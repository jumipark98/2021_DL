# %% [markdown]
# # HW04
# Deep Learning, GIST RT5101-01, 2021, Spring, (Tue/Thurs 2:30~3:45)
# ***
#
# ### Segmentation using fully convolutional network & U-Net
#
# Your homework consists of the following two-step.
#
# 1. Build a U-Net.
#
# 2. Build a U-Net like model.
#
# 3. Compare the results (1. & 2.) with GroundTruth
#
# The codes for loading the **Semantic Boundaries Dataset** are given.
#
# <br>
#
# ### How to submit your homework
# Submit your jupyter notebook file with the filename of  *HW04_studentnumber.ipynb*  on GEL
# Ex) HW04_20184021.ipynb
#
# ### Submission deadline
# 2021.06.02, Wednesday 23:59 (PM)
#
# ### Plagiarism
# We encourage you to discuss this homework with your friends or TA, but you should write your own code.

# %% [markdown]
# ## About the U-Net
#
# - U-Net is a segmentation network based on fully convolutional network. The key idea of U-Net is applying the cropped feature map concatenation between the downsampling path and upsampling path.
#
# - ref : https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/
#
# ![대체 텍스트](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %% [markdown]
# ## About Semantic Boundaries Datasety
#
# - Hariharan (2011) created the Semantic Boundaries Dataset(henceforth abbreviated as SBD) and the associated benchmark to evaluate the task of predicting semantic contours, as opposed to semantic segmentations. While semantic segmentation aims to predict the pixels that lie inside the object, SBD interested in predicting the pixels that lie on the boundary of the object.
#
# - ref : http://home.bharathh.info/pubs/codes/SBD/download.html
#
# ![대체 텍스트](https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/grouping/icons/semantic_contours.png)
#
# ### Dataset
# The **SBD** currently contains annotations from **11355 images** taken from the **PASCAL VOC 2011 dataset**.These images were annotated on Amazon Mechanical Turk and the conflicts between the segmentations were resolved manually. For each image, They provide both category-level and instance-level segmentations and boundaries. The segmentations and boundaries provided are for the **20 object categories** in the **VOC 2011 challenge**.
#
# ### Class Definition
#
# - Aeroplane
# - Bicycle
# - Bird
# - Boat
# - Bottle
# - Bus
# - Car
# - Cat
# - Chair
# - Cow
# - Dining Table
# - Dog
# - Horse
# - Motorbike
# - Person
# - Potted Plant
# - Sheep
# - Sofa
# - Train
# - TV Monitor

# %% [markdown]
# ## **Guide: Load Semantic Boundary Dataset**
# ---
# Before building your segmentation model, download **Semantic Boundary Dataset**.

# %% [markdown]
# - Download **Semantic Boundary Dataset**. It takes about 5 ~ 10 minutes.
#
# - You can check the number of dataset by printing ```len(dataset)```
#
# - If ```Error: Destination path './cls' already exists``` occurs, set the ```download``` option as ```False```

# %%
import torchvision
import matplotlib.pyplot as plt

train_dataset = torchvision.datasets.SBDataset(root='./', image_set='train', mode='segmentation', download=False)
test_dataset = torchvision.datasets.SBDataset(root='./', image_set='val', mode='segmentation',download=False)

print('Number of train images: {}'.format(len(train_dataset)))
print('Number of test images: {}'.format(len(test_dataset)))

image_index = 1
image, target = train_dataset[image_index]
# Out:
# Number of train images: 8498
# Number of test images: 2857

# %% [markdown]
# - Check the input image and its corresponding mask

# %%
plt.title('RGB Image')
plt.imshow(image)

# %%
plt.title('Mask Image')
plt.imshow(target, cmap='gray')

# %% [markdown]
# Define ```transform```, ```dataset``` and ```dataloader```.
#
# In the case of ```SBDataset```, the transform function takes two inputs (```image``` and ```target```).
#
# Note that the ```interpolation``` option of ```Resize``` in ```target_transform``` is **nearest neighbor** since the default option is bilinear.
#
# <br>
#
# <p style="color:#FF0000";><b> !! caution !! </b></p>
#
# <p style="color:#FF0000";><b> Target mask should not be interpolated. </b></p>

# %%
import torch
import numpy as np
import torchvision.transforms as transforms
from PIL import Image

#TODO: change value with your code.
IMAGE_S = 224
BATCH_S = 8

def transform(image, target):
    image_transform = transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S)),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224,0.225))
    ])

    target_transform =  transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S), interpolation=Image.NEAREST),
        np.asarray,
        torch.LongTensor
    ])

    return image_transform(image), target_transform(target)

train_dataset = torchvision.datasets.SBDataset(root='./', image_set='train', mode='segmentation', transforms=transform)
test_dataset = torchvision.datasets.SBDataset(root='./', image_set='val', mode='segmentation', transforms=transform)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=BATCH_S, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=BATCH_S, shuffle=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 1. Build U-Net model (30%)

# %% [markdown]
# - **step 1.** Build U-Net by using FCN layer (10%)
#     - output channel size must be same with number of classes
#     - (Hint: Use ```torch.cat``` function for concat)
#
# - **step 2.** Train your own model with **SBD** (10%)
# - **step 3.** After training, evaluate your network on test dataset and report the test accuracy. Use the pixel-wise accuracy as a metric. (10%)
#
# $$ PixelWiseAccuracy = {NumberOfCorrectPixels \over NumberOfTotalPixels} \times 100 $$
#
# - **Do not use someone's sample code or web code.** (but, you can use your own HW code)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#TODO: define your dataset class number
CLASS_NUM = 21
def double_conv(in_channels, out_channels):
        return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True)
    )

class UNet(nn.Module):

    def __init__(self, n_class=CLASS_NUM):
        super(UNet, self).__init__()
        self.dconv_down1 = double_conv(3, 64)
        self.dconv_down2 = double_conv(64, 128)
        self.dconv_down3 = double_conv(128, 256)
        self.dconv_down4 = double_conv(256, 512)
        self.dconv_down5 = double_conv(512, 1024)

        self.maxpool = nn.MaxPool2d(2)
        self.upsample4 = nn.ConvTranspose2d(1024, 1024, kernel_size=2, stride=2)
        self.upsample3 = nn.ConvTranspose2d(512, 512, kernel_size=2, stride=2)
        self.upsample2 = nn.ConvTranspose2d(256, 256, kernel_size=2, stride=2)
        self.upsample1 = nn.ConvTranspose2d(128, 128, kernel_size=2, stride=2)

        self.dconv_up4 = double_conv(512 + 1024, 512)
        self.dconv_up3 = double_conv(256 + 512, 256)
        self.dconv_up2 = double_conv(128 + 256, 128)
        self.dconv_up1 = double_conv(128 + 64, 64)
        
        self.conv_last1 = nn.Conv2d(64, n_class, 1)
   
        
    def forward(self, x):
        conv1 = self.dconv_down1(x)
        x = self.maxpool(conv1)

        conv2 = self.dconv_down2(x)
        x = self.maxpool(conv2)

        conv3 = self.dconv_down3(x)
        x = self.maxpool(conv3)

        conv4 = self.dconv_down4(x)
        x = self.maxpool(conv4)

        x = self.dconv_down5(x)
        
        x = self.upsample4(x)
        x = torch.cat([x,conv4], dim=1)

        x = self.dconv_up4(x)
        x = self.upsample3(x)
        x = torch.cat([x, conv3], dim=1) 

        x = self.dconv_up3(x) 
        x = self.upsample2(x)
        x = torch.cat([x, conv2], dim=1)

        x = self.dconv_up2(x)
        x = self.upsample1(x)
        x = torch.cat([x, conv1], dim=1)
        
        x = self.dconv_up1(x) 
        output = self.conv_last1(x) 
        

        return output

# %%
device = torch.device('cuda:0')
num_epochs = 50
model = UNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
train_loss = []
test_loss = []
train_pixacc = []
test_pixacc = []
for epoch in range(num_epochs):
    total, correct = 0, 0
    
    for i, (images, labels) in enumerate(train_loader):
        
        images, labels = images.to(device), labels.to(device)
        labels_ = labels.unsqueeze(1)


        outputs= model(images)

        loss = criterion(outputs,labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0) * labels.size(1) * labels.size(2)
        correct += (predicted == labels).sum().item()
        
       
    print('Epoch: {}/{}, Loss: {:.4f}, Training Accuracy: {:.4f}%'.
                format(epoch + 1, num_epochs, loss.item(), 100 * correct / total))
    
    train_pixacc.append(100 * correct / total)
    train_loss.append(loss.item())
    
    with torch.no_grad():
        total, correct = 0, 0
    
        for i, (images, labels) in enumerate(test_loader):

            images, labels = images.to(device), labels.to(device)
            labels_ = labels.unsqueeze(1)


            outputs= model(images)

            loss = criterion(outputs,labels)
           
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0) * labels.size(1) * labels.size(2)
            correct += (predicted == labels).sum().item()

            
        print('Epoch: {}/{}, Loss: {:.4f}, Testing Accuracy: {:.4f}%'.
                    format(epoch + 1, num_epochs, loss.item(), 100 * correct / total))
        
        test_pixacc.append(100 * correct / total)
        test_loss.append(loss.item())

textfile = open("train_pixacc.txt", "w")
for element in train_pixacc:
    textfile.write(str(element) + "\n")
textfile.close()

textfile = open("train_loss.txt", "w")
for element in train_loss:
    textfile.write(str(element) + "\n")
textfile.close()

textfile = open("test_pixacc.txt", "w")
for element in test_pixacc:
    textfile.write(str(element) + "\n")
textfile.close()

textfile = open("test_loss.txt", "w")
for element in test_loss:
    textfile.write(str(element) + "\n")
textfile.close()

torch.save(model.state_dict(), 'standard_unet.pth')
# Out:
# /home/jjong/anaconda3/envs/jumi/lib/python3.6/site-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Epoch: 1/50, Loss: 1.3310, Training Accuracy: 69.4201%
# Epoch: 1/50, Loss: 1.0724, Testing Accuracy: 69.8929%
# Epoch: 2/50, Loss: 1.9285, Training Accuracy: 69.5781%
# Epoch: 2/50, Loss: 1.0183, Testing Accuracy: 69.8933%
# Epoch: 3/50, Loss: 0.9706, Training Accuracy: 69.5634%
# Epoch: 3/50, Loss: 1.0084, Testing Accuracy: 69.8224%
# Epoch: 4/50, Loss: 1.6345, Training Accuracy: 69.5529%
# Epoch: 4/50, Loss: 0.9055, Testing Accuracy: 69.7129%
# Epoch: 5/50, Loss: 1.1045, Training Accuracy: 69.5547%
# Epoch: 5/50, Loss: 1.0425, Testing Accuracy: 69.8924%
# Epoch: 6/50, Loss: 1.2752, Training Accuracy: 69.6428%
# Epoch: 6/50, Loss: 0.9041, Testing Accuracy: 70.0682%
# Epoch: 7/50, Loss: 1.0046, Training Accuracy: 69.6903%
# Epoch: 7/50, Loss: 0.8331, Testing Accuracy: 69.7716%
# Epoch: 8/50, Loss: 1.6740, Training Accuracy: 69.7893%
# Epoch: 8/50, Loss: 0.9106, Testing Accuracy: 70.3333%
# Epoch: 9/50, Loss: 0.6681, Training Accuracy: 69.9188%
# Epoch: 9/50, Loss: 0.8364, Testing Accuracy: 70.1729%
# Epoch: 10/50, Loss: 1.9719, Training Accuracy: 69.9627%
# Epoch: 10/50, Loss: 0.8165, Testing Accuracy: 70.4286%
# Epoch: 11/50, Loss: 2.1960, Training Accuracy: 70.0178%
# Epoch: 11/50, Loss: 0.9153, Testing Accuracy: 70.2929%
# Epoch: 12/50, Loss: 0.3484, Training Accuracy: 70.0752%
# Epoch: 12/50, Loss: 0.8927, Testing Accuracy: 70.5281%
# Epoch: 13/50, Loss: 0.7784, Training Accuracy: 70.0848%
# Epoch: 13/50, Loss: 0.8765, Testing Accuracy: 70.3713%
# Epoch: 14/50, Loss: 1.1006, Training Accuracy: 70.0650%
# Epoch: 14/50, Loss: 0.8676, Testing Accuracy: 70.5561%
# Epoch: 15/50, Loss: 1.2467, Training Accuracy: 70.1651%
# Epoch: 15/50, Loss: 0.8473, Testing Accuracy: 70.5391%
# Epoch: 16/50, Loss: 1.4833, Training Accuracy: 70.1802%
# Epoch: 16/50, Loss: 0.8300, Testing Accuracy: 70.6902%
# Epoch: 17/50, Loss: 0.8889, Training Accuracy: 70.2212%
# Epoch: 17/50, Loss: 0.7854, Testing Accuracy: 70.8318%
# Epoch: 18/50, Loss: 2.0829, Training Accuracy: 70.2908%
# Epoch: 18/50, Loss: 0.7581, Testing Accuracy: 70.6808%
# Epoch: 19/50, Loss: 0.8335, Training Accuracy: 70.3250%
# Epoch: 19/50, Loss: 0.8675, Testing Accuracy: 70.8452%
# Epoch: 20/50, Loss: 2.0020, Training Accuracy: 70.3926%
# Epoch: 20/50, Loss: 0.8458, Testing Accuracy: 70.8454%
# Epoch: 21/50, Loss: 1.5628, Training Accuracy: 70.4682%
# Epoch: 21/50, Loss: 0.8110, Testing Accuracy: 71.0533%
# Epoch: 22/50, Loss: 1.6673, Training Accuracy: 70.5155%
# Epoch: 22/50, Loss: 0.7917, Testing Accuracy: 70.8054%
# Epoch: 23/50, Loss: 1.2988, Training Accuracy: 70.5679%
# Epoch: 23/50, Loss: 0.8148, Testing Accuracy: 71.0443%
# Epoch: 24/50, Loss: 0.8058, Training Accuracy: 70.6705%
# Epoch: 24/50, Loss: 0.7529, Testing Accuracy: 71.0617%
# Epoch: 25/50, Loss: 0.8517, Training Accuracy: 70.6619%
# Epoch: 25/50, Loss: 0.7948, Testing Accuracy: 71.2768%
# Epoch: 26/50, Loss: 1.0742, Training Accuracy: 70.7157%
# Epoch: 26/50, Loss: 0.8038, Testing Accuracy: 71.1872%
# Epoch: 27/50, Loss: 1.7453, Training Accuracy: 70.7689%
# Epoch: 27/50, Loss: 0.9067, Testing Accuracy: 71.3294%
# Epoch: 28/50, Loss: 0.8987, Training Accuracy: 70.8311%
# Epoch: 28/50, Loss: 0.8273, Testing Accuracy: 71.5804%
# Epoch: 29/50, Loss: 0.8705, Training Accuracy: 70.9153%
# Epoch: 29/50, Loss: 0.7643, Testing Accuracy: 71.1920%
# Epoch: 30/50, Loss: 0.4411, Training Accuracy: 71.0030%
# Epoch: 30/50, Loss: 0.7233, Testing Accuracy: 70.9616%
# Epoch: 31/50, Loss: 1.1682, Training Accuracy: 71.0196%
# Epoch: 31/50, Loss: 0.7590, Testing Accuracy: 71.5630%
# Epoch: 32/50, Loss: 0.8623, Training Accuracy: 71.0710%
# Epoch: 32/50, Loss: 0.7577, Testing Accuracy: 71.5754%
# Epoch: 33/50, Loss: 1.5142, Training Accuracy: 71.0774%
# Epoch: 33/50, Loss: 0.6522, Testing Accuracy: 71.6566%
# Epoch: 34/50, Loss: 0.8464, Training Accuracy: 71.1500%
# Epoch: 34/50, Loss: 0.7783, Testing Accuracy: 71.3013%
# Epoch: 35/50, Loss: 0.3043, Training Accuracy: 71.2601%
# Epoch: 35/50, Loss: 0.7943, Testing Accuracy: 71.6050%
# Epoch: 36/50, Loss: 1.0096, Training Accuracy: 71.2346%
# Epoch: 36/50, Loss: 0.6972, Testing Accuracy: 71.6702%
# Epoch: 37/50, Loss: 0.6267, Training Accuracy: 71.2588%
# Epoch: 37/50, Loss: 0.7071, Testing Accuracy: 71.8730%
# Epoch: 38/50, Loss: 1.3573, Training Accuracy: 71.3071%
# Epoch: 38/50, Loss: 0.6966, Testing Accuracy: 71.7998%
# Epoch: 39/50, Loss: 1.3741, Training Accuracy: 71.3657%
# Epoch: 39/50, Loss: 0.6994, Testing Accuracy: 71.7284%
# Epoch: 40/50, Loss: 2.6435, Training Accuracy: 71.3219%
# Epoch: 40/50, Loss: 0.6277, Testing Accuracy: 72.0131%
# Epoch: 41/50, Loss: 0.9848, Training Accuracy: 71.3780%
# Epoch: 41/50, Loss: 0.6110, Testing Accuracy: 71.8838%
# Epoch: 42/50, Loss: 1.6735, Training Accuracy: 71.4565%
# Epoch: 42/50, Loss: 0.6582, Testing Accuracy: 71.9463%
# Epoch: 43/50, Loss: 1.2558, Training Accuracy: 71.4317%
# Epoch: 43/50, Loss: 0.6409, Testing Accuracy: 72.0613%
# Epoch: 44/50, Loss: 1.2120, Training Accuracy: 71.5190%
# Epoch: 44/50, Loss: 0.7841, Testing Accuracy: 72.0940%
# Epoch: 45/50, Loss: 1.1184, Training Accuracy: 71.5390%
# Epoch: 45/50, Loss: 0.5019, Testing Accuracy: 71.4441%
# Epoch: 46/50, Loss: 1.0416, Training Accuracy: 71.5463%
# Epoch: 46/50, Loss: 0.6371, Testing Accuracy: 71.6823%
# Epoch: 47/50, Loss: 1.1241, Training Accuracy: 71.5525%
# Epoch: 47/50, Loss: 0.6145, Testing Accuracy: 71.7462%
# Epoch: 48/50, Loss: 0.7870, Training Accuracy: 71.6359%
# Epoch: 48/50, Loss: 0.6561, Testing Accuracy: 71.9072%
# Epoch: 49/50, Loss: 2.6160, Training Accuracy: 71.6452%
# Epoch: 49/50, Loss: 0.5684, Testing Accuracy: 72.2555%
# Epoch: 50/50, Loss: 0.1961, Training Accuracy: 71.5969%
# Epoch: 50/50, Loss: 0.6928, Testing Accuracy: 72.1823%

# %% [markdown]
# ## Problem 2. Build U-Net like model (50%)

# %% [markdown]
# ![대체 텍스트](https://github.com/gist-ailab/mooc/blob/master/hdlc/unet.png?raw=true)
#
# - **step 1.** Follow the image above, build U-Net like by using FCN layer (20%)
#     - You can define number of feature maps and kernel size freely
#     - output channel size must be same with number of classes
#     - Input and output image size(h,w) must be 388*388
#
# - **step 2.** train your own model with **SBD** (20%)
# - **step 3.** After training, evaluate your network on test dataset and report the test accuracy. Use the pixel-wise accuracy as a metric. (10%)
#
# $$ PixelWiseAccuracy = {NumberOfCorrectPixels \over NumberOfTotalPixels} \times 100 $$
#
# - **Do not copy & paste someone's sample code or web code.** (but, you can use your own HW code)

# %%
import torch
import torchvision
import numpy as np
import torchvision.transforms as transforms
from PIL import Image
import cv2
from albumentations import CLAHE,Compose
#TODO: change value with your code.
IMAGE_S = 224
BATCH_S = 8
clahe = CLAHE(p=0.8)

def transform(image, target):
    image_transform = transforms.Compose([
        transforms.ColorJitter(0.2,0.2,0.2,0),
        transforms.RandomGrayscale(p=0.1),
        transforms.Resize((IMAGE_S, IMAGE_S)),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224,0.225))
    ])

    target_transform =  transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S), interpolation=Image.NEAREST),
        np.asarray,
        torch.LongTensor
    ])
    image =cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    data = {"image":(image)}
    aug = clahe(**data)
    png_img = aug["image"]
    png_img = Image.fromarray(png_img)

    return image_transform(png_img), target_transform(target)
def test_transform(image,target):
    image_transform = transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S)),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224,0.225))
    ])
    target_transform =  transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S), interpolation=Image.NEAREST),
        np.asarray,
        torch.LongTensor
    ])
    image =cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    data = {"image":(image)}
    aug = clahe(**data)
    png_img = aug["image"]
    png_img = Image.fromarray(png_img)

    return image_transform(png_img), target_transform(target)
    
train_dataset = torchvision.datasets.SBDataset(root='./', image_set='train', mode='segmentation', transforms=transform)
test_dataset = torchvision.datasets.SBDataset(root='./', image_set='val', mode='segmentation', transforms=test_transform)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=BATCH_S, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=BATCH_S, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#TODO: define your dataset class number and class name
CLASS_NUM = 21
def double_conv(in_channels, out_channels):
        return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True)
    )

class C_UNet(nn.Module):

    def __init__(self, n_class=CLASS_NUM):
        super(C_UNet, self).__init__()
        self.dconv_down1 = double_conv(3, 64)
        self.dconv_down2 = double_conv(64, 128)
        self.dconv_down3 = double_conv(128, 256)
        self.dconv_down4 = double_conv(256, 512)

        self.maxpool = nn.MaxPool2d(2)
        self.upsample3 = nn.ConvTranspose2d(512, 512, kernel_size=2, stride=2)
        self.upsample2 = nn.ConvTranspose2d(256, 256, kernel_size=2, stride=2)
        self.upsample1 = nn.ConvTranspose2d(128, 128, kernel_size=2, stride=2)

        self.dconv_up3 = double_conv(256 + 512, 256)
        self.dconv_up2 = double_conv(128 + 256, 128)
        self.dconv_up1 = double_conv(128 + 64, 64)
        
        self.conv_last1 = nn.Conv2d(64, n_class, 1)
   
        
    def forward(self, x):
        conv1 = self.dconv_down1(x)
        x = self.maxpool(conv1)

        conv2 = self.dconv_down2(x)
        x = self.maxpool(conv2)

        conv3 = self.dconv_down3(x)
        x = self.maxpool(conv3)

        x = self.dconv_down4(x)
        
        x = self.upsample3(x)
        x = torch.cat([x, conv3], dim=1) 

        x = self.dconv_up3(x) 
        x = self.upsample2(x)
        x = torch.cat([x, conv2], dim=1)

        x = self.dconv_up2(x)
        x = self.upsample1(x)
        x = torch.cat([x, conv1], dim=1)
        
        x = self.dconv_up1(x) 
        output = self.conv_last1(x) 
        

        return output

# %%
device = torch.device('cuda:1')
num_epochs = 300
model = C_UNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
train_loss = []
test_loss = []
train_pixacc = []
test_pixacc = []
for epoch in range(num_epochs):
    total, correct = 0, 0
    
    for i, (images, labels) in enumerate(train_loader):
        
        images, labels = images.to(device), labels.to(device)
        labels_ = labels.unsqueeze(1)


        outputs= model(images)

        loss = criterion(outputs,labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0) * labels.size(1) * labels.size(2)
        correct += (predicted == labels).sum().item()
        
       
    print('Epoch: {}/{}, Loss: {:.4f}, Training Accuracy: {:.4f}%'.
                format(epoch + 1, num_epochs, loss.item(), 100 * correct / total))
    
    train_pixacc.append(100 * correct / total)
    train_loss.append(loss.item())
    
    with torch.no_grad():
        total, correct = 0, 0
    
        for i, (images, labels) in enumerate(test_loader):

            images, labels = images.to(device), labels.to(device)
            labels_ = labels.unsqueeze(1)


            outputs= model(images)

            loss = criterion(outputs,labels)
           
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0) * labels.size(1) * labels.size(2)
            correct += (predicted == labels).sum().item()

            
        print('Epoch: {}/{}, Loss: {:.4f}, Testing Accuracy: {:.4f}%'.
                    format(epoch + 1, num_epochs, loss.item(), 100 * correct / total))
        
        test_pixacc.append(100 * correct / total)
        test_loss.append(loss.item())
    if epoch%20 ==0:
        torch.save(model.state_dict(),'unet_weights/custom/'+str(epoch)+'.pth')
textfile = open("c_train_pixacc.txt", "w")
for element in train_pixacc:
    textfile.write(str(element) + "\n")
textfile.close()

textfile = open("c_train_loss.txt", "w")
for element in train_loss:
    textfile.write(str(element) + "\n")
textfile.close()

textfile = open("c_test_pixacc.txt", "w")
for element in test_pixacc:
    textfile.write(str(element) + "\n")
textfile.close()

textfile = open("c_test_loss.txt", "w")
for element in test_loss:
    textfile.write(str(element) + "\n")
textfile.close()

torch.save(model.state_dict(), 'custom_unet.pth')
# Out:
# ss: 0.6390, Testing Accuracy: 74.8165%
# Epoch: 18/300, Loss: 1.7825, Training Accuracy: 75.2453%
# Epoch: 18/300, Loss: 0.6528, Testing Accuracy: 75.2974%
# Epoch: 19/300, Loss: 1.7270, Training Accuracy: 75.4297%
# Epoch: 19/300, Loss: 0.4147, Testing Accuracy: 74.3559%
# Epoch: 20/300, Loss: 1.0305, Training Accuracy: 75.8346%
# Epoch: 20/300, Loss: 0.4772, Testing Accuracy: 75.5404%
# Epoch: 21/300, Loss: 1.1783, Training Accuracy: 76.2318%
# Epoch: 21/300, Loss: 0.4174, Testing Accuracy: 75.3284%
# Epoch: 22/300, Loss: 1.0958, Training Accuracy: 76.4765%
# Epoch: 22/300, Loss: 0.3927, Testing Accuracy: 75.7128%
# Epoch: 23/300, Loss: 1.1290, Training Accuracy: 76.9511%
# Epoch: 23/300, Loss: 0.2500, Testing Accuracy: 75.1897%
# Epoch: 24/300, Loss: 0.9206, Training Accuracy: 77.2166%
# Epoch: 24/300, Loss: 0.5561, Testing Accuracy: 75.7537%
# Epoch: 25/300, Loss: 0.8174, Training Accuracy: 77.5963%
# Epoch: 25/300, Loss: 0.1287, Testing Accuracy: 75.8970%
# Epoch: 26/300, Loss: 1.7514, Training Accuracy: 77.8250%
# Epoch: 26/300, Loss: 0.2414, Testing Accuracy: 76.0002%
# Epoch: 27/300, Loss: 0.7411, Training Accuracy: 78.2183%
# Epoch: 27/300, Loss: 0.2197, Testing Accuracy: 75.9437%
# Epoch: 28/300, Loss: 0.8596, Training Accuracy: 78.5581%
# Epoch: 28/300, Loss: 0.3213, Testing Accuracy: 76.2289%
# Epoch: 29/300, Loss: 0.8954, Training Accuracy: 78.8604%
# Epoch: 29/300, Loss: 0.3441, Testing Accuracy: 74.4460%
# Epoch: 30/300, Loss: 0.5662, Training Accuracy: 79.1271%
# Epoch: 30/300, Loss: 0.4549, Testing Accuracy: 75.4623%
# Epoch: 31/300, Loss: 0.5649, Training Accuracy: 79.5718%
# Epoch: 31/300, Loss: 0.5108, Testing Accuracy: 76.2531%
# Epoch: 32/300, Loss: 0.4850, Training Accuracy: 79.7993%
# Epoch: 32/300, Loss: 0.3456, Testing Accuracy: 76.4542%
# Epoch: 33/300, Loss: 0.4432, Training Accuracy: 80.2785%
# Epoch: 33/300, Loss: 0.3493, Testing Accuracy: 76.5940%
# Epoch: 34/300, Loss: 0.6923, Training Accuracy: 80.5679%
# Epoch: 34/300, Loss: 0.3210, Testing Accuracy: 75.7292%
# Epoch: 35/300, Loss: 0.4283, Training Accuracy: 80.9319%
# Epoch: 35/300, Loss: 0.3020, Testing Accuracy: 76.0909%
# Epoch: 36/300, Loss: 0.3238, Training Accuracy: 81.2243%
# Epoch: 36/300, Loss: 0.2424, Testing Accuracy: 76.1572%
# Epoch: 37/300, Loss: 0.8745, Training Accuracy: 81.5446%
# Epoch: 37/300, Loss: 0.2691, Testing Accuracy: 76.4562%
# Epoch: 38/300, Loss: 1.1841, Training Accuracy: 82.1801%
# Epoch: 38/300, Loss: 0.5961, Testing Accuracy: 75.0710%
# Epoch: 39/300, Loss: 0.3445, Training Accuracy: 82.1779%
# Epoch: 39/300, Loss: 0.2343, Testing Accuracy: 76.2521%
# Epoch: 40/300, Loss: 0.2189, Training Accuracy: 82.6099%
# Epoch: 40/300, Loss: 0.3284, Testing Accuracy: 76.1428%
# Epoch: 41/300, Loss: 1.1925, Training Accuracy: 82.9841%
# Epoch: 41/300, Loss: 0.3484, Testing Accuracy: 75.4719%
# Epoch: 42/300, Loss: 0.6796, Training Accuracy: 83.3396%
# Epoch: 42/300, Loss: 0.3838, Testing Accuracy: 75.3794%
# Epoch: 43/300, Loss: 1.0690, Training Accuracy: 83.6542%
# Epoch: 43/300, Loss: 0.3121, Testing Accuracy: 75.6393%
# Epoch: 44/300, Loss: 0.6666, Training Accuracy: 84.0695%
# Epoch: 44/300, Loss: 0.5628, Testing Accuracy: 74.2398%
# Epoch: 45/300, Loss: 0.2413, Training Accuracy: 84.4377%
# Epoch: 45/300, Loss: 0.2809, Testing Accuracy: 75.9069%
# Epoch: 46/300, Loss: 0.3755, Training Accuracy: 84.6276%
# Epoch: 46/300, Loss: 0.4600, Testing Accuracy: 75.2527%
# Epoch: 47/300, Loss: 0.5328, Training Accuracy: 84.9830%
# Epoch: 47/300, Loss: 0.4559, Testing Accuracy: 75.8389%
# Epoch: 48/300, Loss: 0.2282, Training Accuracy: 85.4392%
# Epoch: 48/300, Loss: 0.2954, Testing Accuracy: 75.0678%
# Epoch: 49/300, Loss: 0.5853, Training Accuracy: 85.6338%
# Epoch: 49/300, Loss: 0.1649, Testing Accuracy: 75.1637%
# Epoch: 50/300, Loss: 0.8082, Training Accuracy: 85.9241%
# Epoch: 50/300, Loss: 0.3724, Testing Accuracy: 74.3286%
# Epoch: 51/300, Loss: 0.7466, Training Accuracy: 86.1543%
# Epoch: 51/300, Loss: 0.3836, Testing Accuracy: 75.0843%
# Epoch: 52/300, Loss: 0.4298, Training Accuracy: 86.5889%
# Epoch: 52/300, Loss: 0.7415, Testing Accuracy: 75.4295%
# Epoch: 53/300, Loss: 0.5215, Training Accuracy: 86.8418%
# Epoch: 53/300, Loss: 0.7051, Testing Accuracy: 75.3880%
# Epoch: 54/300, Loss: 0.2159, Training Accuracy: 87.0784%
# Epoch: 54/300, Loss: 0.4682, Testing Accuracy: 75.3096%
# Epoch: 55/300, Loss: 0.2190, Training Accuracy: 87.3765%
# Epoch: 55/300, Loss: 0.4452, Testing Accuracy: 75.2236%
# Epoch: 56/300, Loss: 0.6261, Training Accuracy: 87.6390%
# Epoch: 56/300, Loss: 0.4095, Testing Accuracy: 74.7734%
# Epoch: 57/300, Loss: 0.4826, Training Accuracy: 88.0213%
# Epoch: 57/300, Loss: 0.4213, Testing Accuracy: 75.2051%
# Epoch: 58/300, Loss: 0.3759, Training Accuracy: 88.3338%
# Epoch: 58/300, Loss: 0.3188, Testing Accuracy: 75.0464%
# Epoch: 59/300, Loss: 0.2812, Training Accuracy: 88.5183%
# Epoch: 59/300, Loss: 0.3628, Testing Accuracy: 75.3812%
# Epoch: 60/300, Loss: 0.4180, Training Accuracy: 88.7062%
# Epoch: 60/300, Loss: 0.3522, Testing Accuracy: 72.8887%
# Epoch: 61/300, Loss: 0.5298, Training Accuracy: 88.8804%
# Epoch: 61/300, Loss: 0.6815, Testing Accuracy: 75.2694%
# Epoch: 62/300, Loss: 0.5380, Training Accuracy: 89.2710%
# Epoch: 62/300, Loss: 0.4975, Testing Accuracy: 75.3791%
# Epoch: 63/300, Loss: 0.3197, Training Accuracy: 89.4670%
# Epoch: 63/300, Loss: 0.4248, Testing Accuracy: 73.7664%
# Epoch: 64/300, Loss: 0.8786, Training Accuracy: 89.6777%
# Epoch: 64/300, Loss: 0.3646, Testing Accuracy: 74.7977%
# Epoch: 65/300, Loss: 0.1815, Training Accuracy: 89.7826%
# Epoch: 65/300, Loss: 0.3980, Testing Accuracy: 75.3726%
# Epoch: 66/300, Loss: 0.1427, Training Accuracy: 90.1020%
# Epoch: 66/300, Loss: 0.6118, Testing Accuracy: 75.4310%
# Epoch: 67/300, Loss: 0.4694, Training Accuracy: 90.2700%
# Epoch: 67/300, Loss: 0.6188, Testing Accuracy: 75.5685%
# Epoch: 68/300, Loss: 0.4421, Training Accuracy: 90.4627%
# Epoch: 68/300, Loss: 0.4623, Testing Accuracy: 75.5459%
# Epoch: 69/300, Loss: 0.3851, Training Accuracy: 90.7152%
# Epoch: 69/300, Loss: 0.1621, Testing Accuracy: 74.5150%
# Epoch: 70/300, Loss: 0.1196, Training Accuracy: 90.7273%
# Epoch: 70/300, Loss: 0.6696, Testing Accuracy: 74.1397%
# Epoch: 71/300, Loss: 0.1788, Training Accuracy: 90.9986%
# Epoch: 71/300, Loss: 0.3773, Testing Accuracy: 75.2109%
# Epoch: 72/300, Loss: 0.1284, Training Accuracy: 91.1293%
# Epoch: 72/300, Loss: 0.4960, Testing Accuracy: 74.1951%
# Epoch: 73/300, Loss: 0.1251, Training Accuracy: 91.4310%
# Epoch: 73/300, Loss: 0.3223, Testing Accuracy: 75.4816%
# Epoch: 74/300, Loss: 0.5789, Training Accuracy: 91.4408%
# Epoch: 74/300, Loss: 0.4857, Testing Accuracy: 74.4360%
# Epoch: 75/300, Loss: 0.2610, Training Accuracy: 91.5625%
# Epoch: 75/300, Loss: 0.3793, Testing Accuracy: 74.7443%
# Epoch: 76/300, Loss: 0.2413, Training Accuracy: 91.8212%
# Epoch: 76/300, Loss: 0.2683, Testing Accuracy: 74.6928%
# Epoch: 77/300, Loss: 1.0840, Training Accuracy: 91.8710%
# Epoch: 77/300, Loss: 0.2044, Testing Accuracy: 74.3437%
# Epoch: 78/300, Loss: 0.7092, Training Accuracy: 92.0916%
# Epoch: 78/300, Loss: 0.5654, Testing Accuracy: 74.3910%
# Epoch: 79/300, Loss: 0.1491, Training Accuracy: 92.2444%
# Epoch: 79/300, Loss: 0.3110, Testing Accuracy: 75.3726%
# Epoch: 80/300, Loss: 0.1559, Training Accuracy: 92.3418%
# Epoch: 80/300, Loss: 0.4871, Testing Accuracy: 75.5449%
# Epoch: 81/300, Loss: 0.2905, Training Accuracy: 92.5130%
# Epoch: 81/300, Loss: 0.3914, Testing Accuracy: 73.9397%
# Epoch: 82/300, Loss: 0.1055, Training Accuracy: 92.4659%
# Epoch: 82/300, Loss: 0.5474, Testing Accuracy: 74.9720%
# Epoch: 83/300, Loss: 0.1351, Training Accuracy: 92.7717%
# Epoch: 83/300, Loss: 0.3014, Testing Accuracy: 74.6356%
# Epoch: 84/300, Loss: 0.1058, Training Accuracy: 92.9030%
# Epoch: 84/300, Loss: 0.2429, Testing Accuracy: 74.0153%
# Epoch: 85/300, Loss: 0.2729, Training Accuracy: 92.9040%
# Epoch: 85/300, Loss: 0.5009, Testing Accuracy: 73.9473%
# Epoch: 86/300, Loss: 0.2183, Training Accuracy: 92.9235%
# Epoch: 86/300, Loss: 0.3791, Testing Accuracy: 74.9635%
# Epoch: 87/300, Loss: 0.5053, Training Accuracy: 93.0734%
# Epoch: 87/300, Loss: 0.4954, Testing Accuracy: 72.8876%
# Epoch: 88/300, Loss: 0.1184, Training Accuracy: 93.3171%
# Epoch: 88/300, Loss: 0.4782, Testing Accuracy: 74.6871%
# Epoch: 89/300, Loss: 0.2051, Training Accuracy: 93.5547%
# Epoch: 89/300, Loss: 0.3234, Testing Accuracy: 74.9065%
# Epoch: 90/300, Loss: 0.1253, Training Accuracy: 93.3418%
# Epoch: 90/300, Loss: 0.4115, Testing Accuracy: 75.1103%
# Epoch: 91/300, Loss: 0.6775, Training Accuracy: 93.5001%
# Epoch: 91/300, Loss: 0.4782, Testing Accuracy: 74.5095%
# Epoch: 92/300, Loss: 0.1375, Training Accuracy: 93.6499%
# Epoch: 92/300, Loss: 0.5479, Testing Accuracy: 74.5312%
# Epoch: 93/300, Loss: 0.1375, Training Accuracy: 93.6329%
# Epoch: 93/300, Loss: 0.4244, Testing Accuracy: 75.2246%
# Epoch: 94/300, Loss: 0.1761, Training Accuracy: 93.8118%
# Epoch: 94/300, Loss: 0.4365, Testing Accuracy: 75.4043%
# Epoch: 95/300, Loss: 0.1617, Training Accuracy: 93.9423%
# Epoch: 95/300, Loss: 0.3917, Testing Accuracy: 74.9358%
# Epoch: 96/300, Loss: 0.2258, Training Accuracy: 93.9813%
# Epoch: 96/300, Loss: 0.4979, Testing Accuracy: 74.5076%
# Epoch: 97/300, Loss: 0.1795, Training Accuracy: 94.0517%
# Epoch: 97/300, Loss: 0.6952, Testing Accuracy: 75.0883%
# Epoch: 98/300, Loss: 0.4965, Training Accuracy: 94.1056%
# Epoch: 98/300, Loss: 0.5805, Testing Accuracy: 74.5139%
# Epoch: 99/300, Loss: 0.3401, Training Accuracy: 94.1127%
# Epoch: 99/300, Loss: 0.9279, Testing Accuracy: 74.3475%
# Epoch: 100/300, Loss: 0.0916, Training Accuracy: 94.1148%
# Epoch: 100/300, Loss: 0.1706, Testing Accuracy: 74.6592%
# Epoch: 101/300, Loss: 0.1623, Training Accuracy: 94.2124%
# Epoch: 101/300, Loss: 0.5883, Testing Accuracy: 73.3653%
# Epoch: 102/300, Loss: 0.1934, Training Accuracy: 94.0710%
# Epoch: 102/300, Loss: 0.6448, Testing Accuracy: 74.5097%
# Epoch: 103/300, Loss: 0.1037, Training Accuracy: 94.3962%
# Epoch: 103/300, Loss: 0.2838, Testing Accuracy: 75.0094%
# Epoch: 104/300, Loss: 0.3418, Training Accuracy: 94.5966%
# Epoch: 104/300, Loss: 0.5668, Testing Accuracy: 75.2762%
# Epoch: 105/300, Loss: 0.2800, Training Accuracy: 94.4465%
# Epoch: 105/300, Loss: 0.5024, Testing Accuracy: 75.0137%
# Epoch: 106/300, Loss: 0.0419, Training Accuracy: 94.5835%
# Epoch: 106/300, Loss: 0.5317, Testing Accuracy: 75.2372%
# Epoch: 107/300, Loss: 0.1277, Training Accuracy: 94.5849%
# Epoch: 107/300, Loss: 0.7478, Testing Accuracy: 75.6928%
# Epoch: 108/300, Loss: 0.1135, Training Accuracy: 94.7233%
# Epoch: 108/300, Loss: 0.8020, Testing Accuracy: 75.2836%
# Epoch: 109/300, Loss: 0.1329, Training Accuracy: 94.7985%
# Epoch: 109/300, Loss: 0.5457, Testing Accuracy: 75.1120%
# Epoch: 110/300, Loss: 0.1516, Training Accuracy: 94.8691%
# Epoch: 110/300, Loss: 0.3240, Testing Accuracy: 75.4207%
# Epoch: 111/300, Loss: 0.1120, Training Accuracy: 94.8031%
# Epoch: 111/300, Loss: 0.4941, Testing Accuracy: 73.2119%
# Epoch: 112/300, Loss: 0.0796, Training Accuracy: 94.9527%
# Epoch: 112/300, Loss: 0.6375, Testing Accuracy: 75.0602%
# Epoch: 113/300, Loss: 0.4186, Training Accuracy: 94.9007%
# Epoch: 113/300, Loss: 0.2628, Testing Accuracy: 75.4535%
# Epoch: 114/300, Loss: 0.0722, Training Accuracy: 94.8429%
# Epoch: 114/300, Loss: 0.5695, Testing Accuracy: 74.9487%
# Epoch: 115/300, Loss: 0.1502, Training Accuracy: 95.0789%
# Epoch: 115/300, Loss: 0.5575, Testing Accuracy: 74.3020%
# Epoch: 116/300, Loss: 0.3558, Training Accuracy: 94.9491%
# Epoch: 116/300, Loss: 0.4894, Testing Accuracy: 74.5062%
# Epoch: 117/300, Loss: 0.0885, Training Accuracy: 95.2245%
# Epoch: 117/300, Loss: 0.6523, Testing Accuracy: 75.1185%
# Epoch: 118/300, Loss: 0.1339, Training Accuracy: 95.2119%
# Epoch: 118/300, Loss: 0.6063, Testing Accuracy: 74.9948%
# Epoch: 119/300, Loss: 0.1390, Training Accuracy: 95.0400%
# Epoch: 119/300, Loss: 0.4345, Testing Accuracy: 75.2719%
# Epoch: 120/300, Loss: 0.1093, Training Accuracy: 94.9439%
# Epoch: 120/300, Loss: 0.3247, Testing Accuracy: 74.1906%
# Epoch: 121/300, Loss: 0.1250, Training Accuracy: 95.3272%
# Epoch: 121/300, Loss: 0.3431, Testing Accuracy: 74.3405%
# Epoch: 122/300, Loss: 0.0450, Training Accuracy: 95.1056%
# Epoch: 122/300, Loss: 0.4773, Testing Accuracy: 74.7502%
# Epoch: 123/300, Loss: 0.0636, Training Accuracy: 95.5349%
# Epoch: 123/300, Loss: 0.5587, Testing Accuracy: 75.1271%
# Epoch: 124/300, Loss: 0.1067, Training Accuracy: 95.3775%
# Epoch: 124/300, Loss: 0.5892, Testing Accuracy: 75.3427%
# Epoch: 125/300, Loss: 0.1429, Training Accuracy: 95.4467%
# Epoch: 125/300, Loss: 0.5128, Testing Accuracy: 74.8596%
# Epoch: 126/300, Loss: 0.1107, Training Accuracy: 95.3371%
# Epoch: 126/300, Loss: 0.4468, Testing Accuracy: 74.9632%
# Epoch: 127/300, Loss: 0.1051, Training Accuracy: 95.3384%
# Epoch: 127/300, Loss: 0.7182, Testing Accuracy: 75.1775%
# Epoch: 128/300, Loss: 0.2261, Training Accuracy: 95.5522%
# Epoch: 128/300, Loss: 0.4994, Testing Accuracy: 75.8149%
# Epoch: 129/300, Loss: 0.1060, Training Accuracy: 95.7148%
# Epoch: 129/300, Loss: 0.3212, Testing Accuracy: 75.2943%
# Epoch: 130/300, Loss: 0.1243, Training Accuracy: 95.6654%
# Epoch: 130/300, Loss: 0.4520, Testing Accuracy: 74.9808%
# Epoch: 131/300, Loss: 0.0465, Training Accuracy: 95.3496%
# Epoch: 131/300, Loss: 0.6029, Testing Accuracy: 74.6826%
# Epoch: 132/300, Loss: 0.0931, Training Accuracy: 95.6663%
# Epoch: 132/300, Loss: 0.5984, Testing Accuracy: 75.3319%
# Epoch: 133/300, Loss: 0.0918, Training Accuracy: 95.8159%
# Epoch: 133/300, Loss: 0.4792, Testing Accuracy: 75.3444%
# Epoch: 134/300, Loss: 0.0782, Training Accuracy: 95.6853%
# Epoch: 134/300, Loss: 0.2997, Testing Accuracy: 74.5296%
# Epoch: 135/300, Loss: 0.2735, Training Accuracy: 95.6719%
# Epoch: 135/300, Loss: 0.4310, Testing Accuracy: 75.0914%
# Epoch: 136/300, Loss: 0.0364, Training Accuracy: 95.8247%
# Epoch: 136/300, Loss: 0.2832, Testing Accuracy: 74.4528%
# Epoch: 137/300, Loss: 0.1225, Training Accuracy: 95.6077%
# Epoch: 137/300, Loss: 0.5479, Testing Accuracy: 74.9828%
# Epoch: 138/300, Loss: 0.1867, Training Accuracy: 95.7966%
# Epoch: 138/300, Loss: 0.4925, Testing Accuracy: 75.1367%
# Epoch: 139/300, Loss: 0.1224, Training Accuracy: 95.9087%
# Epoch: 139/300, Loss: 0.2332, Testing Accuracy: 74.4923%
# Epoch: 140/300, Loss: 0.1234, Training Accuracy: 95.6301%
# Epoch: 140/300, Loss: 0.3977, Testing Accuracy: 75.0987%
# Epoch: 141/300, Loss: 0.1224, Training Accuracy: 95.8938%
# Epoch: 141/300, Loss: 0.2740, Testing Accuracy: 75.2406%
# Epoch: 142/300, Loss: 0.0839, Training Accuracy: 95.8598%
# Epoch: 142/300, Loss: 0.5454, Testing Accuracy: 75.4587%
# Epoch: 143/300, Loss: 0.0508, Training Accuracy: 96.0608%
# Epoch: 143/300, Loss: 0.4950, Testing Accuracy: 75.4467%
# Epoch: 144/300, Loss: 0.1274, Training Accuracy: 96.0440%
# Epoch: 144/300, Loss: 0.6351, Testing Accuracy: 75.5583%
# Epoch: 145/300, Loss: 0.1123, Training Accuracy: 95.9465%
# Epoch: 145/300, Loss: 0.6423, Testing Accuracy: 75.1488%
# Epoch: 146/300, Loss: 0.2208, Training Accuracy: 95.9620%
# Epoch: 146/300, Loss: 0.6199, Testing Accuracy: 75.3003%
# Epoch: 147/300, Loss: 0.1293, Training Accuracy: 96.0424%
# Epoch: 147/300, Loss: 0.3887, Testing Accuracy: 75.1900%
# Epoch: 148/300, Loss: 0.1670, Training Accuracy: 95.9704%
# Epoch: 148/300, Loss: 0.4911, Testing Accuracy: 75.2429%
# Epoch: 149/300, Loss: 0.1576, Training Accuracy: 95.7800%
# Epoch: 149/300, Loss: 0.5873, Testing Accuracy: 75.3998%
# Epoch: 150/300, Loss: 0.0935, Training Accuracy: 95.9270%
# Epoch: 150/300, Loss: 0.5700, Testing Accuracy: 75.4728%
# Epoch: 151/300, Loss: 0.1220, Training Accuracy: 96.2227%
# Epoch: 151/300, Loss: 0.4324, Testing Accuracy: 75.1881%
# Epoch: 152/300, Loss: 0.3037, Training Accuracy: 96.2063%
# Epoch: 152/300, Loss: 0.2692, Testing Accuracy: 74.7477%
# Epoch: 153/300, Loss: 0.1150, Training Accuracy: 96.0121%
# Epoch: 153/300, Loss: 0.3496, Testing Accuracy: 74.4828%
# Epoch: 154/300, Loss: 0.1021, Training Accuracy: 96.1432%
# Epoch: 154/300, Loss: 0.4362, Testing Accuracy: 74.3434%
# Epoch: 155/300, Loss: 0.1704, Training Accuracy: 96.1826%
# Epoch: 155/300, Loss: 0.4588, Testing Accuracy: 73.8550%
# Epoch: 156/300, Loss: 0.0692, Training Accuracy: 96.0118%
# Epoch: 156/300, Loss: 0.6578, Testing Accuracy: 75.2735%
# Epoch: 157/300, Loss: 0.0919, Training Accuracy: 96.1411%
# Epoch: 157/300, Loss: 0.5031, Testing Accuracy: 75.5195%
# Epoch: 158/300, Loss: 0.2533, Training Accuracy: 96.2703%
# Epoch: 158/300, Loss: 0.6424, Testing Accuracy: 75.5103%
# Epoch: 159/300, Loss: 0.0789, Training Accuracy: 96.2877%
# Epoch: 159/300, Loss: 0.4270, Testing Accuracy: 75.1577%
# Epoch: 160/300, Loss: 0.0575, Training Accuracy: 96.0257%
# Epoch: 160/300, Loss: 0.6672, Testing Accuracy: 74.9138%
# Epoch: 161/300, Loss: 0.3342, Training Accuracy: 96.3329%
# Epoch: 161/300, Loss: 0.7132, Testing Accuracy: 75.1446%
# Epoch: 162/300, Loss: 0.0862, Training Accuracy: 96.4110%
# Epoch: 162/300, Loss: 0.6082, Testing Accuracy: 74.8757%
# Epoch: 163/300, Loss: 0.0906, Training Accuracy: 96.1835%
# Epoch: 163/300, Loss: 0.5873, Testing Accuracy: 75.0507%
# Epoch: 164/300, Loss: 0.0365, Training Accuracy: 96.5132%
# Epoch: 164/300, Loss: 0.7959, Testing Accuracy: 75.4594%
# Epoch: 165/300, Loss: 0.0791, Training Accuracy: 96.1849%
# Epoch: 165/300, Loss: 0.7786, Testing Accuracy: 75.2449%
# Epoch: 166/300, Loss: 0.2131, Training Accuracy: 95.7963%
# Epoch: 166/300, Loss: 0.6918, Testing Accuracy: 74.4792%
# Epoch: 167/300, Loss: 0.0893, Training Accuracy: 96.4200%
# Epoch: 167/300, Loss: 0.3119, Testing Accuracy: 75.3366%
# Epoch: 168/300, Loss: 0.1587, Training Accuracy: 96.3819%
# Epoch: 168/300, Loss: 0.3195, Testing Accuracy: 75.2615%
# Epoch: 169/300, Loss: 0.3010, Training Accuracy: 96.4665%
# Epoch: 169/300, Loss: 0.3664, Testing Accuracy: 75.3950%
# Epoch: 170/300, Loss: 0.0610, Training Accuracy: 96.5109%
# Epoch: 170/300, Loss: 0.6844, Testing Accuracy: 74.3872%
# Epoch: 171/300, Loss: 0.0716, Training Accuracy: 96.3467%
# Epoch: 171/300, Loss: 0.4847, Testing Accuracy: 74.8812%
# Epoch: 172/300, Loss: 0.0978, Training Accuracy: 96.0798%
# Epoch: 172/300, Loss: 0.6921, Testing Accuracy: 75.3642%
# Epoch: 173/300, Loss: 0.0436, Training Accuracy: 96.3622%
# Epoch: 173/300, Loss: 0.5754, Testing Accuracy: 75.3111%
# Epoch: 174/300, Loss: 0.3571, Training Accuracy: 96.5058%
# Epoch: 174/300, Loss: 0.5430, Testing Accuracy: 74.9225%
# Epoch: 175/300, Loss: 0.3317, Training Accuracy: 96.3549%
# Epoch: 175/300, Loss: 0.3858, Testing Accuracy: 75.1180%
# Epoch: 176/300, Loss: 0.1072, Training Accuracy: 96.0439%
# Epoch: 176/300, Loss: 0.5199, Testing Accuracy: 75.0001%
# Epoch: 177/300, Loss: 0.0413, Training Accuracy: 96.6629%
# Epoch: 177/300, Loss: 0.6245, Testing Accuracy: 75.3296%
# Epoch: 178/300, Loss: 0.0283, Training Accuracy: 96.3569%
# Epoch: 178/300, Loss: 0.7678, Testing Accuracy: 75.7382%
# Epoch: 179/300, Loss: 0.1179, Training Accuracy: 96.5036%
# Epoch: 179/300, Loss: 0.3996, Testing Accuracy: 75.0729%
# Epoch: 180/300, Loss: 0.0490, Training Accuracy: 96.5945%
# Epoch: 180/300, Loss: 0.5328, Testing Accuracy: 75.7254%
# Epoch: 181/300, Loss: 0.2055, Training Accuracy: 96.0706%
# Epoch: 181/300, Loss: 0.8330, Testing Accuracy: 75.1217%
# Epoch: 182/300, Loss: 0.0780, Training Accuracy: 96.5662%
# Epoch: 182/300, Loss: 0.9701, Testing Accuracy: 75.4509%
# Epoch: 183/300, Loss: 0.0818, Training Accuracy: 96.6115%
# Epoch: 183/300, Loss: 0.8256, Testing Accuracy: 75.3908%
# Epoch: 184/300, Loss: 0.1140, Training Accuracy: 96.5759%
# Epoch: 184/300, Loss: 0.8201, Testing Accuracy: 75.3687%
# Epoch: 185/300, Loss: 0.1473, Training Accuracy: 95.2602%
# Epoch: 185/300, Loss: 0.8635, Testing Accuracy: 75.6320%
# Epoch: 186/300, Loss: 0.1498, Training Accuracy: 96.5173%
# Epoch: 186/300, Loss: 0.7722, Testing Accuracy: 75.4209%
# Epoch: 187/300, Loss: 0.0885, Training Accuracy: 96.6763%
# Epoch: 187/300, Loss: 0.5419, Testing Accuracy: 75.4183%
# Epoch: 188/300, Loss: 0.0813, Training Accuracy: 96.7060%
# Epoch: 188/300, Loss: 0.5937, Testing Accuracy: 75.3532%
# Epoch: 189/300, Loss: 0.1359, Training Accuracy: 96.7021%
# Epoch: 189/300, Loss: 0.7950, Testing Accuracy: 75.6187%
# Epoch: 190/300, Loss: 0.0430, Training Accuracy: 95.4818%
# Epoch: 190/300, Loss: 0.6875, Testing Accuracy: 75.1234%
# Epoch: 191/300, Loss: 0.0652, Training Accuracy: 96.4771%
# Epoch: 191/300, Loss: 0.5704, Testing Accuracy: 74.9880%
# Epoch: 192/300, Loss: 0.1634, Training Accuracy: 96.7182%
# Epoch: 192/300, Loss: 0.8590, Testing Accuracy: 75.5600%

# %% [markdown]
# ## Problem 3. Compare the results (1. & 2.) with GroundTruth (20%)

# %% [markdown]
# - Visualize your models results with ```plt.subplot()```
# - You can use any method, function but it should be comparable to each result.
#
#      ex) | GT img |, | Unet result img |, | YourModel result img |

# %%
import torch
import torchvision
import numpy as np
import torchvision.transforms as transforms
from PIL import Image
import cv2
from albumentations import CLAHE,Compose
#TODO: change value with your code.
IMAGE_S = 224
BATCH_S = 8
clahe = CLAHE(p=0.8)

def test_transform(image,target):
    image_transform = transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S)),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224,0.225))
    ])
    target_transform =  transforms.Compose([
        transforms.Resize((IMAGE_S, IMAGE_S), interpolation=Image.NEAREST),
        np.asarray,
        torch.LongTensor
    ])
    image =cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    data = {"image":(image)}
    aug = clahe(**data)
    png_img = aug["image"]
    png_img = Image.fromarray(png_img)

    return image_transform(png_img), target_transform(target)

test_dataset = torchvision.datasets.SBDataset(root='./', image_set='val', mode='segmentation', transforms=test_transform)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=BATCH_S, shuffle=False)

# %%
import matplotlib.pyplot as plt
### U-net

device = torch.device('cuda:0')
std_unet = UNet()
cus_unet = C_UNet()
std_unet.load_state_dict(torch.load('unet_weights/std/160.pth'))
cus_unet.load_state_dict(torch.load('unet_weights/custom/160.pth'))
std_unet = std_unet.to(device)
cus_unet = cus_unet.to(device)
total = 0
correct1 = 0
correct2 = 0
for i,(image,label) in enumerate(test_loader):
    image,label = image.to(device),label.to(device)
    std_output = std_unet(image)
    cus_output = cus_unet(image)
    
    _,std_pred = torch.max(std_output.data,1)
    _,cus_pred = torch.max(cus_output.data,1)
  


    
    plt.subplot(1,3,1)
    plt.title('GT image')
    plt.imshow(label[0].cpu().numpy())
    plt.subplot(1,3,2)
    plt.title('Standard Unet')
    plt.imshow(std_pred[0].cpu().numpy())
    plt.subplot(1,3,3)
    plt.title('Custom Unet')
    plt.imshow(cus_pred[0].cpu().numpy())
    plt.show()
# Out:
# /home/jjong/anaconda3/envs/jumi/lib/python3.6/site-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /home/jjong/anaconda3/envs/jumi/lib/python3.6/site-packages/torchvision/transforms/transforms.py:60: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   img = t(img)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e1bb27cbf2d6> in <module>
#      19     _,std_pred = torch.max(std_output.data,1)
#      20     _,cus_pred = torch.max(cus_output.data,1)
# ---> 21     t
#      22
#      23
#
# NameError: name 't' is not defined

# %%
import matplotlib.pypolt as plt

#TODO: draw the graph with plt.subplot().
